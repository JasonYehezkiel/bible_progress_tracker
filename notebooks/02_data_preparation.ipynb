# %%
# Import libraries
from pathlib import Path
import pandas as pd
import warnings
import json
import sys

# suppress warnings in notebook
warnings.filterwarnings('ignore')

# add src to path
sys.path.append(str(Path('../').resolve()))

from annotation.bible_reference_annotator import BibleReferenceAnnotator

# %%
df = pd.read_csv('..\data\processed\cleaned_messages.csv')

print(f'Total messages: {len(df)}')
print(f'\nDataFrame shape: {df.shape}')
print(f'\nColumns: {df.columns.tolist()}')
# Out:
# Total messages: 17191
#
# DataFrame shape: (17191, 3)
#
# Columns: ['timestamp', 'sender', 'message']

# %%
df.head(15)
# Out:
#               timestamp                   sender  \
# 0   2020-08-02 11:52:41  dr. Andreas C.N., Fp.B.
# 1   2020-08-02 11:52:51       Lenny Pandjidharma
# 2   2020-08-02 11:53:17       Lenny Pandjidharma
# 3   2020-08-02 12:20:41                 Oma Lisa
# 4   2020-08-02 12:22:35                   Mfitri
# 5   2020-08-02 12:51:17              Sim Ay Tjan
# 6   2020-08-02 13:01:32            Tjunfebelyana
# 7   2020-08-02 14:22:31                 Oma Lisa
# 8   2020-08-02 14:26:58       Lenny Pandjidharma
# 9   2020-08-02 15:03:11                        🎍
# 10  2020-08-02 18:36:31            Endang Surati
# 11  2020-08-02 20:22:57          Melanie Chandra
# 12  2020-08-02 20:23:31        Vik. Dessy Waiman
# 13  2020-08-02 20:29:44            Endang Surati
# 14  2020-08-02 20:57:21                 Oma Lisa
#
#                                               message
# 0             Siap terimakasih sudah diadd di grup 🙏🏻
# 1                                           sami2 ...
# 2   untuk peraturan group dan tata pelaksanaan ......
# 3   Thanks Lenny.t Lisa ikut ya spytdk cpt pikun a...
# 4                                     Ok,makasih ci 🙏
# 5                                       Thanks Len.🙏🏼
# 6                                         Thanks Len🙏
# 7               Mulak kapan dan jam brp Lenny.Gbu txs
# 8                       Dimulainya besok, Tante Lisa.
# 9                                     Baik, tks. Gbu🙏
# 10                            Terima kasih bu Lenny🙏🙏
# 11  Jadi yg cycle 2 sehari cuma 1 pasal aja ya bu?...
# 12                                       Dua pasal bu
# 13  Selamat malam bu Dessy, dan selamat bpk \ ibu....
# 14             Terima kasih ibu Dessi .good night Gbu

# %%
with open("../data/bible_references.json", "r", encoding="utf-8") as f:
    bible_books = json.load(f)

annotator = BibleReferenceAnnotator(bible_books)

annotated_df = annotator.annotate_dataframe(df, text_column='message')

# %%
annotated_df.head(15)
# Out:
#               timestamp                   sender  \
# 0   2020-08-02 11:52:41  dr. Andreas C.N., Fp.B.
# 1   2020-08-02 11:52:51       Lenny Pandjidharma
# 2   2020-08-02 11:53:17       Lenny Pandjidharma
# 3   2020-08-02 12:20:41                 Oma Lisa
# 4   2020-08-02 12:22:35                   Mfitri
# 5   2020-08-02 12:51:17              Sim Ay Tjan
# 6   2020-08-02 13:01:32            Tjunfebelyana
# 7   2020-08-02 14:22:31                 Oma Lisa
# 8   2020-08-02 14:26:58       Lenny Pandjidharma
# 9   2020-08-02 15:03:11                        🎍
# 10  2020-08-02 18:36:31            Endang Surati
# 11  2020-08-02 20:22:57          Melanie Chandra
# 12  2020-08-02 20:23:31        Vik. Dessy Waiman
# 13  2020-08-02 20:29:44            Endang Surati
# 14  2020-08-02 20:57:21                 Oma Lisa
#
#                                               message bible_references  \
# 0             Siap terimakasih sudah diadd di grup 🙏🏻               []
# 1                                           sami2 ...               []
# 2   untuk peraturan group dan tata pelaksanaan ......               []
# 3   Thanks Lenny.t Lisa ikut ya spytdk cpt pikun a...               []
# 4                                     Ok,makasih ci 🙏               []
# 5                                       Thanks Len.🙏🏼               []
# 6                                         Thanks Len🙏               []
# 7               Mulak kapan dan jam brp Lenny.Gbu txs               []
# 8                       Dimulainya besok, Tante Lisa.               []
# 9                                     Baik, tks. Gbu🙏               []
# 10                            Terima kasih bu Lenny🙏🙏               []
# 11  Jadi yg cycle 2 sehari cuma 1 pasal aja ya bu?...               []
# 12                                       Dua pasal bu               []
# 13  Selamat malam bu Dessy, dan selamat bpk \ ibu....               []
# 14             Terima kasih ibu Dessi .good night Gbu               []
#
#     bible_ref_count intent ner_spans
# 0                 0  OTHER        []
# 1                 0  OTHER        []
# 2                 0  OTHER        []
# 3                 0  OTHER        []
# 4                 0  OTHER        []
# 5                 0  OTHER        []
# 6                 0  OTHER        []
# 7                 0  OTHER        []
# 8                 0  OTHER        []
# 9                 0  OTHER        []
# 10                0  OTHER        []
# 11                0  OTHER        []
# 12                0  OTHER        []
# 13                0  OTHER        []
# 14                0  OTHER        []

# %%
annotated_df['bible_ref_count'].value_counts()
# Out:
# bible_ref_count
# 2     13958
# 0      1022
# 4       978
# 3       724
# 1       247
# 6       106
# 8        59
# 5        30
# 10       22
# 7        15
# 12        8
# 11        7
# 9         7
# 14        4
# 21        1
# 20        1
# 18        1
# 17        1
# Name: count, dtype: int64

# %%
annotated_df[annotated_df["bible_ref_count"] == 0]
# Out:
#                  timestamp                   sender  \
# 0      2020-08-02 11:52:41  dr. Andreas C.N., Fp.B.
# 1      2020-08-02 11:52:51       Lenny Pandjidharma
# 2      2020-08-02 11:53:17       Lenny Pandjidharma
# 3      2020-08-02 12:20:41                 Oma Lisa
# 4      2020-08-02 12:22:35                   Mfitri
# ...                    ...                      ...
# 17185  2022-06-23 09:18:28           susianawati309
# 17187  2022-07-01 15:14:59        Vik. Dessy Waiman
# 17188  2022-07-01 15:18:49                Andrie HG
# 17189  2022-07-01 15:15:16                Andrie HG
# 17190  2022-07-01 15:15:50        Vik. Dessy Waiman
#
#                                                  message bible_references  \
# 0                Siap terimakasih sudah diadd di grup 🙏🏻               []
# 1                                              sami2 ...               []
# 2      untuk peraturan group dan tata pelaksanaan ......               []
# 3      Thanks Lenny.t Lisa ikut ya spytdk cpt pikun a...               []
# 4                                        Ok,makasih ci 🙏               []
# ...                                                  ...              ...
# 17185                                               Baik               []
# 17187  Selamta Sore bpk ibu, krn Group BRC3 sdh dibua...               []
# 17188                            ~ Andrie HG ditambahkan               []
# 17189                       Terima kasih bu dessy 🙏🏽🙏🏽🙏🏽               []
# 17190                               Sama-sama pak Andrie               []
#
#        bible_ref_count intent ner_spans
# 0                    0  OTHER        []
# 1                    0  OTHER        []
# 2                    0  OTHER        []
# 3                    0  OTHER        []
# 4                    0  OTHER        []
# ...                ...    ...       ...
# 17185                0  OTHER        []
# 17187                0  OTHER        []
# 17188                0  OTHER        []
# 17189                0  OTHER        []
# 17190                0  OTHER        []
#
# [1022 rows x 7 columns]

# %%
annotated_df[annotated_df["bible_ref_count"] == 1]
# Out:
#                  timestamp              sender  \
# 15     2020-08-02 21:39:18   Vik. Dessy Waiman
# 85     2020-08-04 09:30:11         Ibu Kartika
# 91     2020-08-04 11:49:49           Andrie HG
# 141    2020-08-05 07:47:42         Ibu Kartika
# 142    2020-08-05 07:49:37       Yozef Tjandra
# ...                    ...                 ...
# 16766  2022-06-09 12:13:52  Lenny Pandjidharma
# 16771  2022-06-09 20:21:52        Ruri Handoko
# 16837  2022-06-11 23:45:01             scarlet
# 16896  2022-06-14 10:52:05              piccer
# 17119  2022-06-21 22:07:00                 Tom
#
#                                                  message  \
# 15                                     1 Raja dan 2 Raja
# 85     Kejadian 4:20 (TB) Ada itu melahirkan Yabal; d...
# 91     Ini kisahnya di skip2 😁\nJadi waktu kain takut...
# 141     O iya sdh dijawab di guideline Kej 6 sih rasanya
# 142    Krn Kalo Nephilim tmsuk menantunya Nuh, brti k...
# ...                                                  ...
# 16766                                 3 Yoh - Wah 2 done
# 16771                                 3 Yoh 1 - Yudas ☑️
# 16837                                2 Yoh- wahyu 1 done
# 16896                                   yudas-why 5 done
# 17119  Wahyu 22:21 (TB) Kasih karunia Tuhan Yesus men...
#
#                                         bible_references  bible_ref_count  \
# 15     [{'book_start': 'dan', 'start_chapter': 2, 'bo...                1
# 85     [{'book_start': 'Kejadian', 'start_chapter': 4...                1
# 91     [{'book_start': 'Kejadian', 'start_chapter': 5...                1
# 141    [{'book_start': 'Kej', 'start_chapter': 6, 'bo...                1
# 142    [{'book_start': 'kej', 'start_chapter': 6, 'bo...                1
# ...                                                  ...              ...
# 16766  [{'book_start': 'Wah', 'start_chapter': 2, 'bo...                1
# 16771  [{'book_start': '3 Yoh', 'start_chapter': 1, '...                1
# 16837  [{'book_start': 'wahyu', 'start_chapter': 1, '...                1
# 16896  [{'book_start': 'why', 'start_chapter': 5, 'bo...                1
# 17119  [{'book_start': 'Wahyu', 'start_chapter': 22, ...                1
#
#                 intent                                          ner_spans
# 15     PROGRESS_REPORT  [{'start': 7, 'end': 10, 'label': 'BOOK', 'tex...
# 85     PROGRESS_REPORT  [{'start': 0, 'end': 8, 'label': 'BOOK', 'text...
# 91     PROGRESS_REPORT  [{'start': 157, 'end': 165, 'label': 'BOOK', '...
# 141    PROGRESS_REPORT  [{'start': 31, 'end': 34, 'label': 'BOOK', 'te...
# 142    PROGRESS_REPORT  [{'start': 135, 'end': 138, 'label': 'BOOK', '...
# ...                ...                                                ...
# 16766  PROGRESS_REPORT  [{'start': 8, 'end': 11, 'label': 'BOOK', 'tex...
# 16771  PROGRESS_REPORT  [{'start': 0, 'end': 5, 'label': 'BOOK', 'text...
# 16837  PROGRESS_REPORT  [{'start': 7, 'end': 12, 'label': 'BOOK', 'tex...
# 16896  PROGRESS_REPORT  [{'start': 6, 'end': 9, 'label': 'BOOK', 'text...
# 17119  PROGRESS_REPORT  [{'start': 0, 'end': 5, 'label': 'BOOK', 'text...
#
# [247 rows x 7 columns]

# %%
annotated_df[annotated_df["bible_ref_count"] > 2]
# Out:
#                  timestamp                     sender  \
# 104    2020-08-04 15:21:49              Tjunfebelyana
# 122    2020-08-04 21:11:48                        Tan
# 159    2020-08-05 15:57:58              Tjunfebelyana
# 176    2020-08-05 21:12:35                     Yoshua
# 248    2020-08-06 21:05:59              Tjunfebelyana
# ...                    ...                        ...
# 16870  2022-06-13 18:05:52                BL katering
# 16882  2022-06-14 04:45:54                BL katering
# 16998  2022-06-17 21:30:07              Tjunfebelyana
# 17051  2022-06-20 07:22:13  Helen Fransiska Margarita
# 17186  2022-06-25 22:12:26                Tejo Jayadi
#
#                                         message  \
# 104      Kej 3-4 selesai.\nJojo Kej 3-4 selesai
# 122                    Kej 1 - 2 ✅\nKej 3 - 4 ✅
# 159       Kej 5-6 selesai\nJojo kej 5-6 selesai
# 176                    Kej 1 - 2 ✅\nKej 3 - 4 ✅
# 248             Kej 7-8 done\nJojo kej 7-8 done
# ...                                         ...
# 16870   1yoh 1-5 done\n2yoh 1 done\n3yoh 1 done
# 16882             Yudas 1 done\nWahyu 1-10 done
# 16998                  Jojo 1 Yoh 4-Why 12 done
# 17051  Wahyu 19-20 done\nWahyu 21- 22 FINISH 🥰🙏
# 17186        Wahyu 19-20 done\nWahyu 21-22 done
#
#                                         bible_references  bible_ref_count  \
# 104    [{'book_start': 'Kej', 'start_chapter': 3, 'bo...                4
# 122    [{'book_start': 'Kej', 'start_chapter': 1, 'bo...                4
# 159    [{'book_start': 'Kej', 'start_chapter': 5, 'bo...                4
# 176    [{'book_start': 'Kej', 'start_chapter': 1, 'bo...                4
# 248    [{'book_start': 'Kej', 'start_chapter': 7, 'bo...                4
# ...                                                  ...              ...
# 16870  [{'book_start': '1yoh', 'start_chapter': 1, 'b...                4
# 16882  [{'book_start': 'Wahyu', 'start_chapter': 1, '...                3
# 16998  [{'book_start': '1 Yoh', 'start_chapter': 4, '...                3
# 17051  [{'book_start': 'Wahyu', 'start_chapter': 19, ...                4
# 17186  [{'book_start': 'Wahyu', 'start_chapter': 19, ...                4
#
#                 intent                                          ner_spans
# 104    PROGRESS_REPORT  [{'start': 0, 'end': 3, 'label': 'BOOK', 'text...
# 122    PROGRESS_REPORT  [{'start': 0, 'end': 3, 'label': 'BOOK', 'text...
# 159    PROGRESS_REPORT  [{'start': 0, 'end': 3, 'label': 'BOOK', 'text...
# 176    PROGRESS_REPORT  [{'start': 0, 'end': 3, 'label': 'BOOK', 'text...
# 248    PROGRESS_REPORT  [{'start': 0, 'end': 3, 'label': 'BOOK', 'text...
# ...                ...                                                ...
# 16870  PROGRESS_REPORT  [{'start': 0, 'end': 4, 'label': 'BOOK', 'text...
# 16882  PROGRESS_REPORT  [{'start': 13, 'end': 18, 'label': 'BOOK', 'te...
# 16998  PROGRESS_REPORT  [{'start': 5, 'end': 10, 'label': 'BOOK', 'tex...
# 17051  PROGRESS_REPORT  [{'start': 0, 'end': 5, 'label': 'BOOK', 'text...
# 17186  PROGRESS_REPORT  [{'start': 0, 'end': 5, 'label': 'BOOK', 'text...
#
# [1964 rows x 7 columns]

# %%
n = 1000

progress_df = annotated_df[annotated_df['intent'] == "PROGRESS_REPORT"].sample(
    n=n,
    random_state=42
)

other_df = annotated_df[annotated_df['intent'] == "OTHER"].sample(
    n=n,
    random_state=42
)

sample_df = pd.concat([progress_df, other_df]).sample(
    frac=1,
    random_state=42
).reset_index(drop=True)

# %%
sample_df = sample_df[["message", "intent"]]

# %%
import json

tasks = []

for _, row in sample_df.iterrows():
    text = row["message"]
    weak_label = row.get("intent", None)  # your weak label; can be None

    result = []
    if weak_label is not None:
        result.append({
            "from_name": "intent",
            "to_name": "text",
            "type": "choices",
            "value": {"choices": [weak_label]}
        })

    task = {
        "data": {"text": text},
        "predictions": [{"result": result}] if result else []
    }

    tasks.append(task)

# Save JSON for Label Studio
with open("../data/processed/label_studio_intents.json", "w", encoding="utf-8") as f:
    json.dump(tasks, f, ensure_ascii=False, indent=2)

print("Saved: label_studio_intents.json")
# Out:
# Saved: label_studio_intents.json

# %% [markdown]
# ### Intent Classification

# %%
intent_df = annotated_df[['message', 'has_bible_ref']]

# %%
intent_df.rename(columns={"has_bible_ref": "label"}, inplace=True)

# %%
print(f'\nintent_df Columns: {intent_df.columns.tolist()}')
# Out:
# intent_df Columns: ['message', 'label']

# %%
intent_df.to_csv('..\data\processed\intent_messages_labeled.csv', index=False, encoding="utf-8-sig")

# %% [markdown]
# ### LLM Finetuning

# %%
finetuning_df = annotated_df[['message', 'bible_references', 'bible_ref_count']]

# %%
finetuning_df.rename(columns={
    "message" : "input",
    "bible_references" : "response"}, inplace=True)

# %%
print(f'\finetuning_df Columns: {finetuning_df.columns.tolist()}')
# Out:
# inetuning_df Columns: ['input', 'response', 'bible_ref_count']

# %%
def make_strata(x):
    if x == 0:
        return "zero"
    elif x == 1:
        return "one"
    else:
        return "more_than_one"
    
finetuning_df["strata"] = finetuning_df["bible_ref_count"].apply(make_strata)

# %%
strata_counts = finetuning_df["strata"].value_counts(normalize=True)
strata_counts
# Out:
# strata
# one              0.803212
# zero             0.126502
# more_than_one    0.070285
# Name: proportion, dtype: float64

# %%
train_samples = []
test_samples = []

train_size = 1000
test_size = 250

for strata, proporation in strata_counts.items():
    strata_df = finetuning_df[finetuning_df["strata"] == strata].sample(frac=1, random_state=42)

    n_train = round(proporation * train_size)
    n_test = round(proporation * test_size)

    train_samples.append(strata_df.iloc[:n_train])
    test_samples.append(strata_df.iloc[n_train:n_train+n_test])


train_df = pd.concat(train_samples).sample(frac=1, random_state=42).reset_index(drop=True)
test_df  = pd.concat(test_samples).sample(frac=1, random_state=42).reset_index(drop=True)

# %%
test_df
# Out:
#                          input  \
# 0             Kej 17 - 20 done
# 1               Maz 27-28 done
# 2               Maz 96-97 done
# 3              Filipi 1-2 done
# 4    2 sam 1-1raja-raja 4 done
# ..                         ...
# 246             Yes 23-24 done
# 247             Kis 11-22 done
# 248          2 Raj 8 - 11 done
# 249             Bil 12-13 done
# 250               Yes 5-6 done
#
#                                               response  bible_ref_count strata
# 0    [{'book_start': 'Kej', 'start_chapter': 17, 'b...                1    one
# 1    [{'book_start': 'Maz', 'start_chapter': 27, 'b...                1    one
# 2    [{'book_start': 'Maz', 'start_chapter': 96, 'b...                1    one
# 3    [{'book_start': 'Filipi', 'start_chapter': 1, ...                1    one
# 4    [{'book_start': '2 sam', 'start_chapter': 1, '...                1    one
# ..                                                 ...              ...    ...
# 246  [{'book_start': 'Yes', 'start_chapter': 23, 'b...                1    one
# 247  [{'book_start': 'Kis', 'start_chapter': 11, 'b...                1    one
# 248  [{'book_start': '2 Raj', 'start_chapter': 8, '...                1    one
# 249  [{'book_start': 'Bil', 'start_chapter': 12, 'b...                1    one
# 250  [{'book_start': 'Yes', 'start_chapter': 5, 'bo...                1    one
#
# [251 rows x 4 columns]

# %%
instruction_text = (
    "Ekstrak semua referensi Alkitab dari teks berikut. "
    "Keluarkan hanya JSON array tanpa penjelasan. "
    "Jika tidak ada referensi, keluarkan array kosong."
)

train_df["instruction"] = instruction_text

train_df = train_df[["instruction", "input", "response"]]
test_df = test_df[["input", "response"]]

# %%
test_df
# Out:
#                          input  \
# 0             Kej 17 - 20 done
# 1               Maz 27-28 done
# 2               Maz 96-97 done
# 3              Filipi 1-2 done
# 4    2 sam 1-1raja-raja 4 done
# ..                         ...
# 246             Yes 23-24 done
# 247             Kis 11-22 done
# 248          2 Raj 8 - 11 done
# 249             Bil 12-13 done
# 250               Yes 5-6 done
#
#                                               response
# 0    [{'book_start': 'Kej', 'start_chapter': 17, 'b...
# 1    [{'book_start': 'Maz', 'start_chapter': 27, 'b...
# 2    [{'book_start': 'Maz', 'start_chapter': 96, 'b...
# 3    [{'book_start': 'Filipi', 'start_chapter': 1, ...
# 4    [{'book_start': '2 sam', 'start_chapter': 1, '...
# ..                                                 ...
# 246  [{'book_start': 'Yes', 'start_chapter': 23, 'b...
# 247  [{'book_start': 'Kis', 'start_chapter': 11, 'b...
# 248  [{'book_start': '2 Raj', 'start_chapter': 8, '...
# 249  [{'book_start': 'Bil', 'start_chapter': 12, 'b...
# 250  [{'book_start': 'Yes', 'start_chapter': 5, 'bo...
#
# [251 rows x 2 columns]

# %%
train_df.to_json("../data/processed/finetuning/bible_ref_train.jsonl", 
                 orient="records", lines=True, force_ascii=False)
test_df.to_json("../data/processed/bible_ref_test.jsonl", 
                orient="records", lines=True, force_ascii=False)
